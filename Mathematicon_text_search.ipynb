# %% [markdown]
# # Mathematicon
#
# **Примечание:** На данный момент код не содержит взаимодействия с математической разметкой и представляет собой самую первичную и самую примитивную реализацию поисковика непосредственно по plain texts.

# %%
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import numpy as np
import os
import pandas as pd
from pymorphy2 import MorphAnalyzer
import random
import re
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import time

# %% [markdown]
# Изначально работали с текстами, очищенными от метаинформации.
#
# **Примечание:** впоследствии тексты будут разделены на предложения с помощью `nltk.tokenize.sent_tokenize`, и индексироваться будут именно предложения, а не целиковые тексты; помимо того, будет создана база данных из двух таблиц:
#
# - В первой будут содержаться id текста, название видео, ссылка на видео, раздел математики и уровень сложности материала;
#
# - Во вторую таблицу будут записаны id предложения, id текста, текст предложения.

# %%
path = r"C:\Users\AnAnG\OneDrive\Рабочий стол\texts_to_count"

files = sorted(os.listdir(path))
#print(len(files))
#print(*files, sep="\n")

texts = []

for file in files:
    with open(os.path.join(path, file), "r", encoding="UTF-8") as f:
        text = re.search(r'text: "(.|\n)*"', f.read()).group(0).replace('text: "', "").replace('"', "")
        texts.append(text)

#print(len(texts))
#print(*texts, sep="\n")

# %%
morph = MorphAnalyzer()
stop_words = set(stopwords.words("russian"))

# %% [markdown]
# Препроцессинг текстов включал в себя перевод в нижний регистр, очистку от небуквенных и нечисловых элементов и лемматизацию буквенных элементов (слов) с помощью анализатора `MorphAnalyzer()` бибилиотеки `pymorphy2`.

# %%
def preprocessing(text):
    """
    Функция для получения лемм текста и очистки его от пунктуации
    Аргумент - строка с текстом описания
    Вывод - строка с очищенным готовым к обработке текстом
    """
    text = text.lower()
    tokenizer = RegexpTokenizer(r"[а-я0-9ё]+")
    text_tokenized = tokenizer.tokenize(text)
    lemmas = [
        morph.parse(word)[0].normal_form
        for word in text_tokenized
        if word.isalpha() == True
    ]
    return " ".join(lemmas)

# %%
preprocessed_texts = []

for i in range(len(texts)):
    preprocessed_texts.append(preprocessing(texts[i]))

# %% [markdown]
# Тексты мы индексировали посредством составления их tf-idf матрицы и сохранения ее в отдельный файл, чтобы не пришлось при каждом новом запуске кода считать матрицу заново.

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(preprocessed_texts)

# получаем из TF-IDF матрицы массив
tfidf_array = tfidf_matrix.toarray()

# в файл сохраняем только массив
np.save("tfidf_matrix.npy", tfidf_array)

# %% [markdown]
# В функции поиска близость оценивалась на основании косинусного расстояния. На данный момент максимум в поисковой выдаче - это 5 текстов.

# %%
def search_tfidf(query, vectorizer, tfidf_matrix, texts):
    """
    Функция для поиска по TF-IDF
    Аргументы - строка с текстом запроса, векторизатор для текста запроса,
    матрица препроцесснутых текстов, тексты для выдачи
    Вывод - результаты поиска на основе косинусного расстояния
    """
    # считаем матрицу запроса
    query_vector = vectorizer.transform([query])
    similarities = cosine_similarity(query_vector, tfidf_matrix).flatten()
    top_idx = similarities.argsort()[-5:][::-1] # выбор топ-5 наиболее подходящих запросов
    results = [texts[i] for i in top_idx]
    return results

# %% [markdown]
# Повторюсь, реализация пока максимально примитивная, не включает работу с разметкой математическими тегами, а с точки зрения выдачи, пока не содержит метаинформацию текстов и показывает тексты целиком, а не предложения. В ячейке ниже приведен пример выдачи на запрос *пополам*.

# %%
# примитивная первичная реализация поисковика

query_text = input("Введите запрос: ")

# поиск по TF-IDF
results_tfidf = search_tfidf(
    query_text, vectorizer, np.load("tfidf_matrix.npy"), texts
)

print(*results_tfidf, sep="\n\n-------\n\n")
# Out:
# Введите запрос:  пополам
# В этом видео мы посмотрим решение неравенств методом интервалов, видео преимущественно для учеников девятых классов, которые в конце года сдают экзамен. Итак, квадратное неравенство какое-нибудь, например, такое, ну и знак меньше либо равно нуля. Такое задание встречается в первой части в блоке “алгебра” под номером восемь. Итак, квадратное неравенство решается с помощью уравнения, то есть мы всё это дело приравниваем к нулю. Вычисляем дискриминант, то есть бэ квадрат минус четыре а цэ, получается девять минус четыре умножить на минус четыре, всё в итоге равно двадцать пять. Теперь находим корни. Формула корней – минус бэ плюс минус корень из дискриминанта поделить на два а. Первый корень – это, берём второй коэффициент с обратным знаком, то есть, если здесь стоит минус три, то с обратным знаком будет, наоборот, три. Итак, три плюс пять поделить на два, и второй корень – это три минус пять поделить на два. Здесь получится восемь пополам – это четыре, здесь минус два пополам, то есть минус один. Теперь мы выставляем эти корни на числовую прямую. Сюда пишем минус один, сюда пишем четыре. Если знак неравенства – меньше либо равно, то есть нестрогий знак, тогда кружочки рисуем закрашенными, если знак был бы строго меньше, тогда кружочки вот эти рисовали бы прозрачными. Итак, дальше нам нужно определить знаки на интервалах, то есть в центральном интервале мы для этого берём число ноль. В принципе, можем взять любое число из этого интервала. Ноль чем удобен, что его легко подставлять, можно просто иксы закрыть, и получится оставшееся минус четыре, то есть на втором интервале знак минус. Для правого интервала, например, можно взять пятёрку, получится двадцать пять минус пятнадцать и минус четыре, то есть это получается двадцать пять минус девятнадцать, это больше нуля. Если больше нуля, то значит мы всём интервале будет знак плюс. Да, подставляем вот в то место, где мы переходим к уравнению. Дальше из этого интервала, например, если подставить минус два, то получится четыре плюс шесть и минус четыре, то есть тоже больше нуля. Как можно быстро определить знаки на интервалах? Смотрим сюда. В неравенстве у нас квадратичная функция, график этой функции будет парабола с ветвями вверх, выглядит примерно вот так. Ветви вверх, потому что коэффициент при икс квадрате больше нуля. Итак, эта часть параболы выше оси икс, то есть знак плюс, средняя часть параболы ниже оси икс, то есть знак минус, ну и правая часть тоже выше, то есть плюс. Сами вот эти точки минус один и четыре означают точки пересечения с осью икс. И мы теперь пишем ответ, то есть икс принадлежит от минус единицы до четырёх, то есть берём отрицательный интервал, потому что знак меньше либо равно нуля. Скобки пишем квадратные, потому что знак допускает равенство, то есть есть палочка. Если бы, допустим, знак был без палочки, то есть меньше нуля, кружочки мы бы нарисовали прозрачные и скобки были бы круглые.
#
# -------
#
скорость как будто бы дельта эс поделить на дельта тэ. И если мы устремляем дельта тэ к нулю, - мы не очень понимаем, что это такое, хотя физики про это говорят ещё седьмом классе, да, - если мы устремляем дельта тэ к нулю, то вот то, что получится, это называется мгновенной скоростью. Вот откуда берётся производная и вот почему она везде нужна. Потому что она у нас в жизни прямо везде, постоянно. По определению, если у вас есть функция эф от икс, то производная – это предел при дельта икс стремящимся к нулю, эф от икс плюс дельта икс минус эф от икс поделить на дельта икс. Если такой предел существует, он называется производной нашей функции в точке икс. Мы берём какой-то момент времени, ну, не времени, икс координаты, вот если икс – это время, а эф – это как перемещение зависит от времени, то это просто скорость. Производная – это просто скорость изменения функции. Вы берёте два близких момента времени, да, две близкие координаты по икс, смотрите разные значения функции, делите на изменение переменной. Вот, если есть предел этого отношения, - пока мы не очень понимаем, что такое предел, не будем сейчас очень строго в это вылезать, да, - если есть предел этого отношения, то он называется производной. Окей, поняли, что такое производная. Почему же производная синуса равна косинусу? Ну, давайте начнём издалека, начнём с более простых вещей. Смотрите, всякие производные от многочленов, что икс штрих равно один, помните, да? Икс квадрат штрих равно два икс и так далее, икс в степени ка штрих равно ка штрих равно ка на икс в степени ка минус один. Откуда всё это взялось? Ну, давайте, поговорим. С этим-то вообще всё просто, да, почему икс штрих равно один? По ...
#
# -------
#
# Здравствуйте, дорогие друзья, мы продолжаем цикл видеоуроков, посвящённых решению уравнений и неравенств с параметрами. Предлагаем вашему вниманию пятый видео урок: Решение иррациональных неравенств с параметрами. Урок пятый - решение иррациональных неравенств с параметрами. Ну и, опять же, на конкретном примере, на примере конкретного иррационального неравенства с параметрами мы разберём, как в принципе решаются подобные примеры. Вот давайте запишем какой-нибудь такой пример, корень из икс плюс а меньше, чем а минус корень из икс. Значит, вот такое неравенство требуется решить при различных значениях параметра. Если при решении уравнений можно найти область допустимых значений отдельно и решать уравнение, а потом смотреть, входит ли корень или корни в область допустимых значений, когда входит, когда нет, то я рекомендую при решении неравенств область допустимых значений, накладывать условия, да, возникающие из области допустимых значений, сразу же, и записывали это всё системой, и смотреть, решать, постоянно тянуть, вот, всю систему, потому что это на каждом шаге нужно всё отслеживать, как это всё взаимодействует. Особенно когда у нас есть ещё и параметры. Ну вот это неравенство очень хорошее, хорошее для дальнейшего действия, но для анализа лучше записать равносильное неравенство, перенести этот корень в левую часть. То есть, вот, лучше анализировать неравенство в таком виде. Это, конечно, два абсолютно равносильных неравенства, но, значит, области допустимых значений что здесь, что здесь у корней одна и та же, икс плюс а больше равно нуля, неотрицательное выражение, да, и здесь второй корень, икс, стоящий под корнем, тоже должен быть неотрицательным. И в таком, и в таком виде это видно, но сумма корней, которые определены, да, вот при этих условиях, она тоже является величиной неотрицательной, значит правая часть, которая должна быть больше, должна быть однозначно положительной величиной. А должно быть больше нуля. Ну а теперь, когда мы вот это всё записали, зато у нас и здесь стоит неотрицательная величина, и здесь неотрицательная, даже положительная, да, то всё это неравенство можно возводить в квадрат. Но я уже сказал, что первое неравенство, оно равносильно, и для дальнейшего действия, а именно вот я имел в виду для возведения в квадрат, лучше возводить в квадрат исходное неравенство, проще получается выражение, ну что мы и сделаем. Значит, квадрат левой части, знак неравенства тот же, и квадрат правой части, квадрат первого плюс квадрат второго минус удвоенное произведение первого на второе. Вот все четыре условия, которым, значит, это система, да, из четырёх условий, которой равносильно исходное неравенство. Значит, в данном случае исходное неравенство, либо это, либо это, да, равносильно, вот, пересечению, вот, четырёх условий, или этой системе. Итак, осталось только решить эту систему. Ну, начнём мы с того, что первое запишем, а больше нуля, здесь у нас икс больше или равен нуля и икс больше или равен минус а. Если у нас а больше нуля, то минус а, естественно, число отрицательное, и если икс удовлетворяет вот этому условию, то тому тем более. То есть мы оставляем только икс больше или равно нуля. Так, ну и здесь упрощаем, иксы у нас уничтожаются, да, а величина положительная, строго положительная, на неё можно сократить, здесь общий множитель везде есть - а. И мы тогда что получим? С иксом переносим сюда, без икса, наоборот, вправо. Значит, здесь у нас будет два корня из икс, если мы это всё перенесём влево, да, и сократим на а, а здесь будет а минус один. Значит, вот эта система равносильна этой. Теперь смотрите, при икс больше или равно нуля корень определён, является величиной неотрицательной, а эта величина больше, значит, это неравенство имеет смысл и имеет решение, когда правая часть строго положительна. То есть мы сразу можем написать, что у нас а не просто больше нуля, а а минус один больше или равно нуля, а минус один больше нуля, это строго положительная величина, значит, а больше единицы. Значит, решение  ...
#
# -------
#
# Сегодняшняя лекция посвящена принципу Дирихле. Напомню вкратце что есть принцип Дирихле. У нас есть эн плюс один заяц, и мы распихиваем эти эн плюс один зайца по эн клеткам. Тогда я хочу сказать, что в одной из клеток будет минимум два зайца, ой, то в одной из клеток будет больше либо равно двух зайцев. Можно немножко эту задачу в обратную сторону раскрутить. Представим себе, что у нас в каждой клетке будет меньше двух зайцев, максимум один тогда. Тогда мы распихали эн зайцев по одному в каждую клетку, и оставшегося эн плюс одного зайца нам придётся точно запихнуть в какую-то уже занятую клетку, и там появятся два зайца. Вот этот принцип Дирихле обобщается: если мы будем распихивать два эн плюс один зайцев по эн клеткам, то как минимум в одной клетке будет три зайца и более, и так далее. Также часто, когда упоминают принцип Дирихле, распихивают не зайцев, а голубей, ну, в западной литературе чаще голубей распихивают, а у нас зайцев, вот. Собственно, всё. На этом простом принципе решаются задачи из разных разделов математики. Сейчас я вам это покажу.
# Первая задача такова. В классе имеется тридцать человек. Проходила контрольная по математике. Уникальный ученик Илья совершил тринадцать ошибок в этой контрольной. Известно, что остальные ученики совершали меньшее количество ошибок в этой контрольной. Докажите, что по-крайней мере три ученика совершили одинаковое число ошибок. Могли вообще не ошибиться. Предположим противное, что среди двадцати учеников совершили одинаковое число ошибок максимум два ученика и введём абстрактное понятие клетки. Клетка с номером ноль, с номером один, с номером два и так далее, номер двенадцать... Закодируем ситуацию, что, например, ученица Маша совершила ноль ошибок. Это то же самое, что учениц
# Следующая задача. Тоже на делимость. У нас имеется семь целых чисел. Нужно доказать, что среди них найдётся несколько или хотя бы одно число, сумма которых делится на семь. Пусть икс один, икс два и так далее, икс семь – это данные числа. Рассмотрим числа: игрек один, равное икс один; игрек два, равное икс один плюс икс два и так далее. Игрек семь, равное икс один плюс икс два, плюс икс три, плюс, и так далее, плюс икс семь. Если какой-то из игрек катых делится на семь, то в качестве, ну, например, если игрек третий делится на семь, то тогда я просто беру первое, второе, третье число и говорю, что их сумма делится на семь, всё. Всё классно. Ну, в общем, здесь у нас такое, очевидно, можно сразу записать, что происходит. Если вы на олимпиаде какой-нибудь, конечно, нужно просто проговорить текст, который я проговорил устно, прописать текст, который я проговорил устно. Теперь рассмотрим второй случай: никакой из игреков не делится на семь. Тогда игрек один, игрек два, и так далее, игрек семь дают разные остатки при делении на семь, и не нулевые. Таких остатков у нас шесть: один, два, три, четыре, пять, шесть. И я хочу сказать, что по принципу Дирихле, два из этих чисел будут иметь один и тот же остаток при делении на семь, и минимум существуют два игрек итая и игрек житая с одинаковыми остатками при делении на семь. Ну, тогда мы просто берём разность вот этих игрек итая и игрек житая, и эта разность будет делиться на семь. А с другой стороны, разность игрек итого и игрек житого – это сумма... Ну, из большего если вычитать меньшее, то это будет сумма каких-то иксов, и, значит, я доказал, что как ни крути из семи целых чисел можно выбрать несколько, которые в сумме, для которых сумма делится на семь.
# Перейдём к следующей задаче. Последняя задача на принцип Дирихле, довольно сложная. Двенадцать волейбольных команд сыграли турнир в один круг. Обязательно ли найдутся три команды, что каждая из оставшихся девяти команд проиграла хотя бы одной из этих трёх? Напоминаю вам, что в волейболе не бывает ничьих. Ну, в этой задаче нужно ответить либо да, либо нет. Если да, то предъявить просто пример, как-то построить вот эти три команды, объяснить, что они точно есть. И если нет, то надо какие-то противоречия найти. Вот, ну, подсказка по этой задаче, что, наверное, да, смотрите: если у меня есть три команды, которые победили всех, но, может быть, между собой там как-то разделили пьедестал, то, очевидно, что они, каждая из них, обыграла оставшиеся девять команд. Хорошо? Вот, ну а если у нас турнир был такой хороший, как-то конкурентоспособный, то есть там каждая команда плюс-минус на равных играет с другими, то тогда вот таких тройку лидеров как-то, может быть, не получится выделить, вот. А может быть, и получится. Ну, и мы докажем, что всё-таки получится их выделить, тройку этих лидеров. Давайте подумаем, сколько всего очков разыгрывается. Сколько всего игр было? Игр было… Количество игр, цэ из пяти по два, то есть количество пар… Цэ из двенадцати по два, простите. Это, двенадцать на одиннадцать пополам, и получилось шестьдесят шесть игр. Окей. Ну, то есть у нас есть двенадцать точек, первую эм могу двенадцатью способами выбрать, вторую – одиннадцатью способами, и мне не важен порядок, которым я выбираю эти точки, поэтому получается двенадцать на одиннадцать пополам – шестьдесят шесть игр или шестьдесят шесть очков было разыграно. Поделим это шестьдесят шесть на двенадцать. Сколько это будет... Одиннадцать вторых или пять с половиной. Я хочу сказать следующее, что обязательно найдется одна команда, у которой будет шесть побед. Почему? Ну, предположим противное. Предположим, что все двенадцать команд имеют максимум пять побед. Я предполагаю, что одна команда имеет шесть побед и более. Предположим, что… противное, предположим, что каждая из двенадцати моих команд имеет максимум пять побед. Тогда очков будет разыграно пять умножить на двенадцать, то есть шестьдесят будет очков разыграно. Оставшиеся шесть очков куда пойдут в неудел. Поэтому точно какая-то команда выиграет больше, чем пять, ну, как минимум шесть раз. Вот, выделим эту команду, которая победила своих шесть… в шести играх, а может и больше. Вот, выделим её и шесть команд, которые она точно выиграла, а может быть она и большее количество выиграла, но их уже не будем выделять. Хорошо, осталось у нас пять команд. Сколько очков между собой разыграли вот эти пять команд? Это количество игр между собой вот этих пяти команд. Это по той же формуле будет: цэ из пяти по два, или пять на четыре пополам, то есть десять. И если я теперь десять поделю на пять, то получу два очка. И я хочу сказать, что хотя бы одна команда имеет точно две победы из вот этих вот пяти. Ну, давайте выделим, что вот эта команда победила вот эти две команды. Но если б она победила эту, все, задача уже была б решена. Вот пусть она эти две победила и больше никого. Но, или, мне важно, что она победила точно какие-то две, а три, может быть, и не победила. Хорошо, идём дальше. Но из оставшихся двух команд какая-то да победит. Вот я и нашёл тройку команд, которые, какая-то из них да победила оставшиеся девять, и аккуратно построил для произвольного случая эту тройку команд. Я решил задачу. Здесь, когда вот брал вот это деление, рассматривал это, я как бы к истокам принципа Дирихле переходил.
#
# -------
#
# Центральная предельная теорема. Пусть у нас имеется набор взаимно независимых случайных величин, икс первый, икс второй и так далее, икс энное, и нас интересует поведение суммы этих случайных величин. Как показал Липунов, если у нас есть случайная величина, которая является суммой большого числа взаимно независимых случайных величин, влияние каждой из которых на сумму ничтожно мало, то вот это случайная величина икс имеет распределение близкое к нормальному. Чем больше это количество слагаемых, тем ближе эта случайная величина будет распределена к нормальному закону. Пусть у нас математическое ожидание ка-той случайной величины, входящей в эту сумму равно а ка-тому, а дисперсия равна бэ ка тэ в квадрате. Введём обозначение эс энное равно икс первое плюс икс второе и так далее, плюс икс энное, просто сумма всех случайных величин. А энное это есть сумма дисперсии, сумма математических ожиданий этих случайных величин это есть сумма по ка от единицы до эн а ка тэ, а бэ энное в квадрате это есть ни что иное, как сумма дисперсий этих случайных величин. То есть, сумма по ка от единицы до бэ ка тэ в квадрате. Для нормированной суммы, то есть, для эс энная минус а энная делить на бэ энная функция распределения есть по определению самой функции распределения эф энная следующая. Есть вероятность того, что это нормированная сумма при измерении окажется меньше, чем икс. Последовательности случайных величин икс один, икс два и так далее, икс эн, применима центральная предельная теорема, если при любом икс функция распределения такой нормированной суммы стремится к нормальной функции распределения при эн стремящейся к бесконечности. То есть, лимит при энн стремящейся к бесконечности, вероятности того, что нормированная сумма будет меньше, чем икс, будет ни что иное как функция распределения нормальной случайной величины. То есть, единицу делить на корень из двух пи, интеграл от минус бесконечности до икс, е в степени минус зэт квадрат пополам дэ зэт. В частности, если все случайные величины икс один и так далее одинаково распределены, их дисперсии конечны и отличны от нуля, то их сумме: икс один плюс икс два плюс икс три и так далее, плюс икс эн, применима центральная предельная теорема. Как показал Липунов, что если для некоторого дельта большего нуля предел, при этом стремящийся к бесконечности, суммы по ка от единицы до эн матожидания от модуля икс ка тэ минус а ка тэ в степени два плюс дельта делить на бэ энное в степени два плюс дельта равна нулю, то к последовательности икс один, икс два, икс три и так далее, икс эн применима центральная предельная теорема.
# Рассмотрим пример: пусть монета подбрасывается десять тысяч раз, нам нужно найти вероятность того, что относительная частота выпадения орла отличается от ноль пяти не менее, чем на одну сотую. Напомним, что относительная частота выпадения орла это будет количество бросаний, когда у нас выпал орёл к общему числу подбрасываний монеты, к десяти тысячам. Решение: нам надо найти вероятность того, что вот эта вот сумма делить на количество подбрасываний минус одна вторая будет больше, чем одна сотая, где эн равно десяти тысячам, а эс эн это есть количество выпадения орла. А количество выпадения орла суммируется как? Это есть кси первое плюс кси второе плюс кси третье и так далее, плюс кси энное, кси это есть количество выпадений орла при этом испытании. Понятно, что всё это может принимать значение либо ноль, либо единицы, такая вот случайная величина дискретная, у которой два значения. Математическое ожидание от величины кси и тэ это есть одна вторая. Дисперсия случайной величины кси и тэ обозначим как бэ и тэ в квадрате, это есть одна четвёртая. Тогда по центральной предельной теореме вот такая вот величина, нормированная сумма эс энная минус а энная делить на бэ энная, равная эс энная минус эн умножить на одну вторую, делить на корень квадратный из эн и на одну вторую, имеет распределение близкое к нормальному. А что это означает? Это означает, что мы можем поступить следующим образом: эс энная делить на эн минус одна вторая это равно эс энная минус эн на одну вторую, делить на корень из эн на одну вторую и умножить на единицу, делить на два корня из эн. Отсюда следует, что из неравенства эс эн делить на эн минус одна вторая больше, чем одна сотая, следует вот какое неравенство: что эс энная минус эн умножить на одну вторую, делить на корень из эн и на одну вторую, будет больше, чем два корня из эн, умноженные на одну сотую. Поскольку, эн в нашем случае равна десяти тысячам, то мы получим следующее соотношение: эс эн минус эн на одну вторую делить на корень из эн, умноженный на одну вторую больше, чем в два. Отсюда следует, что вероятность, что вот этот модуль больше, чем два равна единица минус вероятность, что этот же самый модуль меньше, либо равен. Почему? Потому что событие первое является противоположным событию второму, а это есть ни что иное, как единица поскольку у нас вот такая нормированная сумма распределена по закону близкому к нормальному, это есть ни что иное, примерно, как единица минус единица делить на корень из двух пи, интеграл от минус двух до двух, е в степени минус зэт квадрат пополам до зэт. Обратим внимание, что под интегралом у нас стоит четная функция, поэтому это есть два интеграла от нуля до двух е в степени минус зэт квадрат дэ зэт. Такой интеграл: от нуля до двух есть эти минус зэт дэ зэт это табулированная функция. Таблица эта обозначается, как эф от двух, значение этой функции в точке два равно примерно ноль четыре семь семь два. Тогда получаем, что это есть единица минус два умножить на ноль целых четыре тысячи семьсот семьдесят две десятитысячных или это будет равно нулю целых четырёмстам пятидесяти пятидесяти шести десяти тысячам. То есть, вероятность того, что отклонится более, чем на одну сотую при десяти тысячах испытаниях будет равна ноль целых ноль четыре пять шесть.
